# %% [markdown]
# # Univariate Bivariate and Multivariate Analysis
#         Height    Weight   O/P
#         180m      90       Obese
#         160       50       Slim
#         170       78       Fit
#         190       90       Fit
#         175       80       Slim

# %%
# Univariate:  In univariate analysis we only take one feature;and based on the feature we will try to determine what the output is.
# Example: Here with the help of Weight feature we can classify its output i.e Obese,Fit and Slim

# %%
# Bivariate: In bivariate analysis we will taking at least two feature like height and weight

# %%
# Multivariate: more than 3 features

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('iris.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape  #(150,5) i.e 150 records and 5 features
# Out:
# (150, 5)

# %% [markdown]
# ## Univariate Analysis

# %%
df_setosa=df.loc[df['species']=='setosa']

# %%
df_virginica=df.loc[df['species']=='virginica']
df_versicolor=df.loc[df['species']=='versicolor']

# %%
plt.plot(df_setosa['sepal_length'],np.zeros_like(df_setosa['sepal_length']),'o')
plt.plot(df_virginica['sepal_length'],np.zeros_like(df_virginica['sepal_length']),'o')
plt.plot(df_versicolor['sepal_length'],np.zeros_like(df_versicolor['sepal_length']),'o')
plt.xlabel("Petal Length")
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.FacetGrid(df,hue="species",size=5).map(plt.scatter,"sepal_length","sepal_width").add_legend()
plt.show()
# Out:
# /home/ridhhi/anaconda3/envs/dev_lab/lib/python3.7/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Multivariate Analysis

# %%
sns.pairplot(df,hue="species",size=3)
# Out:
# /home/ridhhi/anaconda3/envs/dev_lab/lib/python3.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
